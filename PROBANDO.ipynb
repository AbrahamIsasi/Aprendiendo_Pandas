# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'c:\\Users\\Administrador_BI\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
os.chdir(r'C:\Users\Administrador_BI\Desktop\python_prueba')

# %%
df = pd.read_excel('win.xlsx', usecols=["LIST_ID","CAMPAÑA","TIPIFICACION","DNI","AGENTE"])
df
# Out:
#      LIST_ID CAMPAÑA                TIPIFICACION       DNI  \
# 0        408  WINOUT     AUTORIZA- SIN COBERTURA  46691128
# 1        404  WINOUT         AUTORIZA - AGENDADO  46691128
# 2        404  WINOUT     AUTORIZA- SIN COBERTURA  46691128
# 3        408  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 4        404  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# ..       ...     ...                         ...       ...
# 157      404  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 158      407  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 159      407  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 160      407  WINOUT  AUTORIZA - VOLVER A LLAMAR  46691128
# 161      404  WINOUT  AUTORIZA - VOLVER A LLAMAR  46691128
#
#                               AGENTE
# 0    HAUDE DAVID CALDERON SAN MIGUEL
# 1    HAUDE DAVID CALDERON SAN MIGUEL
# 2    HAUDE DAVID CALDERON SAN MIGUEL
# 3    HAUDE DAVID CALDERON SAN MIGUEL
# 4    HAUDE DAVID CALDERON SAN MIGUEL
# ...

# %%
df
# Out:
#      LIST_ID CAMPAÑA                TIPIFICACION       DNI  \
# 0        408  WINOUT     AUTORIZA- SIN COBERTURA  46691128
# 1        404  WINOUT         AUTORIZA - AGENDADO  46691128
# 2        404  WINOUT     AUTORIZA- SIN COBERTURA  46691128
# 3        408  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 4        404  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# ..       ...     ...                         ...       ...
# 157      404  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 158      407  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 159      407  WINOUT     AUTORIZA- CORTA LLAMADA  46691128
# 160      407  WINOUT  AUTORIZA - VOLVER A LLAMAR  46691128
# 161      404  WINOUT  AUTORIZA - VOLVER A LLAMAR  46691128
#
#                               AGENTE
# 0    HAUDE DAVID CALDERON SAN MIGUEL
# 1    HAUDE DAVID CALDERON SAN MIGUEL
# 2    HAUDE DAVID CALDERON SAN MIGUEL
# 3    HAUDE DAVID CALDERON SAN MIGUEL
# 4    HAUDE DAVID CALDERON SAN MIGUEL
# ...

# %%
pd.read_excel('win.xlsx', sheet_name=2)
# Out:
#       LIST_ID CAMPAÑA      FECHA       TMO  STATUS  \
# 0         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 1         278  WINOUT 2025-10-01  00:00:00  1CEF02
# 2         396  WINOUT 2025-10-01  00:00:00  3NCO01
# 3         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 4         404  WINOUT 2025-10-01  00:00:00  1CEF05
# ...       ...     ...        ...       ...     ...
# 7829      408  WINOUT 2025-10-01       NaN  INCALL
# 7830      408  WINOUT 2025-10-01       NaN  INCALL
# 7831      998  WINOUT 2025-10-01       NaN  INCALL
# 7832      408  WINOUT 2025-10-01       NaN  INCALL
# 7833      372  WINOUT 2025-10-01       NaN  INCALL
#
#                      TIPIFICACION   TELEFONO       DNI  \
# 0         AUTORIZA- CORTA LLAMADA  914922217  74536535
# 1             AUTORIZA - AGENDADO  937647656  74075275
# 2                     NO CONTESTA  992625371  10015709
# 3         AUTORIZA- CORTA LLAMADA  950173921  74417924
# 4     AUTORIZA- NO DESEA-PRODUCTO  933024736  72322895
# ...

# %%
df['LIST_ID'].unique().tolist()
# Out:
# [408, 404, 407, 504, 395, 396, 387, 998, 239, 390, 372, 503]

# %%
df['LIST_ID'].nunique()
# Out:
# 12

# %%
df = pd.read_excel('win.xlsx').head()

# %%
df[['STATUS']]
# Out:
#    STATUS                           AGENTE
# 0  2CNE03  HAUDE DAVID CALDERON SAN MIGUEL
# 1  1CEF02  HAUDE DAVID CALDERON SAN MIGUEL
# 2  2CNE03  HAUDE DAVID CALDERON SAN MIGUEL
# 3  2CNE01  HAUDE DAVID CALDERON SAN MIGUEL
# 4  2CNE01  HAUDE DAVID CALDERON SAN MIGUEL

# %%
df['STATUS'] = '1CEF01'
df
# Out:
#    LIST_ID CAMPAÑA      FECHA       TMO  STATUS             TIPIFICACION  \
# 0      408  WINOUT 2025-10-01  00:20:38  1CEF01  AUTORIZA- SIN COBERTURA
# 1      404  WINOUT 2025-10-01  00:12:44  1CEF01      AUTORIZA - AGENDADO
# 2      404  WINOUT 2025-10-01  00:08:35  1CEF01  AUTORIZA- SIN COBERTURA
# 3      408  WINOUT 2025-10-01  00:04:53  1CEF01  AUTORIZA- CORTA LLAMADA
# 4      404  WINOUT 2025-10-01  00:03:57  1CEF01  AUTORIZA- CORTA LLAMADA
#
#     TELEFONO       DNI                           AGENTE TERMINO_LLAMADA  \
# 0  968050812  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 1  950168047  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 2  945853311  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 3  972819271  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 4  955258851  46691128  HAUDE DAVID CALDERON SAN MIGUEL          AGENTE
#
#   TIPO_LLAMADA      GESTION  AGENDADO  VENTA  VOLVER A LLAMAR  CORTA LLAMADA  \
# ...

# %%
df = pd.read_excel('win.xlsx', sheet_name=2)
# Out:
#       LIST_ID CAMPAÑA      FECHA       TMO  STATUS  \
# 0         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 1         278  WINOUT 2025-10-01  00:00:00  1CEF02
# 2         396  WINOUT 2025-10-01  00:00:00  3NCO01
# 3         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 4         404  WINOUT 2025-10-01  00:00:00  1CEF05
# ...       ...     ...        ...       ...     ...
# 7829      408  WINOUT 2025-10-01       NaN  INCALL
# 7830      408  WINOUT 2025-10-01       NaN  INCALL
# 7831      998  WINOUT 2025-10-01       NaN  INCALL
# 7832      408  WINOUT 2025-10-01       NaN  INCALL
# 7833      372  WINOUT 2025-10-01       NaN  INCALL
#
#                      TIPIFICACION   TELEFONO       DNI  \
# 0         AUTORIZA- CORTA LLAMADA  914922217  74536535
# 1             AUTORIZA - AGENDADO  937647656  74075275
# 2                     NO CONTESTA  992625371  10015709
# 3         AUTORIZA- CORTA LLAMADA  950173921  74417924
# 4     AUTORIZA- NO DESEA-PRODUCTO  933024736  72322895
# ...

# %%
df[df['STATUS'] == '1CEF01']
# Out:
# <bound method DataFrame.nunique of      LIST_ID CAMPAÑA      FECHA       TMO  STATUS      TIPIFICACION  \
# 102      998  WINOUT 2025-10-01  00:01:13  1CEF01  AUTORIZA - VENTA
# 103      404  WINOUT 2025-10-01  00:01:43  1CEF01  AUTORIZA - VENTA
# 104      404  WINOUT 2025-10-01  00:02:05  1CEF01  AUTORIZA - VENTA
# 105      404  WINOUT 2025-10-01  00:02:19  1CEF01  AUTORIZA - VENTA
# 106      271  WINOUT 2025-10-01  00:07:35  1CEF01  AUTORIZA - VENTA
# 107      278  WINOUT 2025-10-01  00:08:25  1CEF01  AUTORIZA - VENTA
# 108      407  WINOUT 2025-10-01  00:09:18  1CEF01  AUTORIZA - VENTA
# 109      407  WINOUT 2025-10-01  00:11:44  1CEF01  AUTORIZA - VENTA
# 110      408  WINOUT 2025-10-01  00:11:47  1CEF01  AUTORIZA - VENTA
# 111      503  WINOUT 2025-10-01  00:12:36  1CEF01  AUTORIZA - VENTA
# 112      227  WINOUT 2025-10-01  00:13:02  1CEF01  AUTORIZA - VENTA
# 113      387  WINOUT 2025-10-01  00:13:44  1CEF01  AUTORIZA - VENTA
# ...

# %%
df[(df['LIST_ID'] >= 250) & (df['STATUS'] == '1CEF01')]
# Out:
# LIST_ID                        31
# CAMPAÑA                        31
# FECHA                          31
# TMO                            31
# STATUS                         31
# TIPIFICACION                   31
# TELEFONO                       31
# DNI                            31
# AGENTE                         31
# TERMINO_LLAMADA                31
# TIPO_LLAMADA                   31
# GESTION                        31
# AGENDADO                       31
# VENTA                          31
# VOLVER A LLAMAR                31
# CORTA LLAMADA                  31
# TIPOLOGÌA                      31
# Unnamed: 17                     0
# Unnamed: 18                     0
# Unnamed: 19                     0
# % De TIPIFICACION               0
# Unnamed: 21                     0
# Unnamed: 22                     0
# Unnamed: 23                     0
# Unnamed: 24                     0
# Unnamed: 25                     0
# TIPIFICACIONES POR AGENTES      0
# ...

# %%
df
# Out:
#       LIST_ID CAMPAÑA      FECHA       TMO  STATUS  \
# 0         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 1         278  WINOUT 2025-10-01  00:00:00  1CEF02
# 2         396  WINOUT 2025-10-01  00:00:00  3NCO01
# 3         396  WINOUT 2025-10-01  00:00:00  2CNE01
# 4         404  WINOUT 2025-10-01  00:00:00  1CEF05
# ...       ...     ...        ...       ...     ...
# 7829      408  WINOUT 2025-10-01       NaN  INCALL
# 7830      408  WINOUT 2025-10-01       NaN  INCALL
# 7831      998  WINOUT 2025-10-01       NaN  INCALL
# 7832      408  WINOUT 2025-10-01       NaN  INCALL
# 7833      372  WINOUT 2025-10-01       NaN  INCALL
#
#                      TIPIFICACION   TELEFONO       DNI  \
# 0         AUTORIZA- CORTA LLAMADA  914922217  74536535
# 1             AUTORIZA - AGENDADO  937647656  74075275
# 2                     NO CONTESTA  992625371  10015709
# 3         AUTORIZA- CORTA LLAMADA  950173921  74417924
# 4     AUTORIZA- NO DESEA-PRODUCTO  933024736  72322895
# ...

# %%
df.iloc[0:21,0:9]
# Out:
#     LIST_ID CAMPAÑA      FECHA       TMO  STATUS                 TIPIFICACION  \
# 0       396  WINOUT 2025-10-01  00:00:00  2CNE01      AUTORIZA- CORTA LLAMADA
# 1       278  WINOUT 2025-10-01  00:00:00  1CEF02          AUTORIZA - AGENDADO
# 2       396  WINOUT 2025-10-01  00:00:00  3NCO01                  NO CONTESTA
# 3       396  WINOUT 2025-10-01  00:00:00  2CNE01      AUTORIZA- CORTA LLAMADA
# 4       404  WINOUT 2025-10-01  00:00:00  1CEF05  AUTORIZA- NO DESEA-PRODUCTO
# 5       404  WINOUT 2025-10-01  00:00:00  2CNE01      AUTORIZA- CORTA LLAMADA
# 6       393  WINOUT 2025-10-01  00:00:00  3NCO01                  NO CONTESTA
# 7       404  WINOUT 2025-10-01  00:00:00  2CNE01      AUTORIZA- CORTA LLAMADA
# 8       998  WINOUT 2025-10-01  00:00:00  3NCO01                  NO CONTESTA
# 9       998  WINOUT 2025-10-01  00:00:00  3NCO01                  NO CONTESTA
# 10      404  WINOUT 2025-10-01  00:00:00  2CNE01      AUTORIZA- CORTA LLAMADA
# ...

# %%
df[(df['TIPIFICACION'] == 'AUTORIZA - AGENDADO') & (df['LIST_ID']== 998)]
# Out:
#       LIST_ID CAMPAÑA      FECHA       TMO  STATUS         TIPIFICACION  \
# 11        998  WINOUT 2025-10-01  00:00:00  1CEF02  AUTORIZA - AGENDADO
# 35        998  WINOUT 2025-10-01  00:00:00  1CEF02  AUTORIZA - AGENDADO
# 38        998  WINOUT 2025-10-01  00:00:00  1CEF02  AUTORIZA - AGENDADO
# 144       998  WINOUT 2025-10-01  00:00:02  1CEF02  AUTORIZA - AGENDADO
# 1523      998  WINOUT 2025-10-01  00:00:14  1CEF02  AUTORIZA - AGENDADO
# 1723      998  WINOUT 2025-10-01  00:00:15  1CEF02  AUTORIZA - AGENDADO
# 1823      998  WINOUT 2025-10-01  00:00:16  1CEF02  AUTORIZA - AGENDADO
# 2223      998  WINOUT 2025-10-01  00:00:18  1CEF02  AUTORIZA - AGENDADO
# 2570      998  WINOUT 2025-10-01  00:00:20  1CEF02  AUTORIZA - AGENDADO
# 3868      998  WINOUT 2025-10-01  00:00:28  1CEF02  AUTORIZA - AGENDADO
# 3961      998  WINOUT 2025-10-01  00:00:29  1CEF02  AUTORIZA - AGENDADO
# 4419      998  WINOUT 2025-10-01  00:00:32  1CEF02  AUTORIZA - AGENDADO
# ...

# %%
df['TMO'].mean
# Out:
# <bound method Series.mean of 0       00:00:00
# 1       00:00:00
# 2       00:00:00
# 3       00:00:00
# 4       00:00:00
#           ...
# 7829         NaN
# 7830         NaN
# 7831         NaN
# 7832         NaN
# 7833         NaN
# Name: TMO, Length: 7834, dtype: object>
