# %%
import pandas as pd

# %%
pd.read_csv('C:\\Users\\Administrador_BI\\Desktop\\VOLCADO_22.csv')
# Out:
# C:\Users\Administrador_BI\AppData\Local\Temp\ipykernel_14900\1022315571.py:1: DtypeWarning: Columns (3,21,23,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('C:\\Users\\Administrador_BI\\Desktop\\VOLCADO_22.csv')
#        Campaña  Empresa                          Nombre         DNI  \
# 0       OUTSJL   GEATEL                          ALIPIO   9156191.0
# 1       OUTSJL   GEATEL  BRUNO SILVESTRE YARANGA GUTIER  42061710.0
# 2       WINOUT  IGLOBAL        CARLOS NOE GORDON CANAYO  47698825.0
# 3       WINOUT  IGLOBAL     CESAR ALBERTO BEJARANO LAZO  43402942.0
# 4       WINOUT  IGLOBAL    CESAR AUGUSTO CORDOVA DURAND  46439605.0
# ...        ...      ...                             ...         ...
# 168810  WINOUT  IGLOBAL       JORGE IGNACIO PUGA GARCIA    74500239
# 168811  WINOUT  IGLOBAL      ILDEFONSO CARTOLIN PESEROS     9252992
# 168812  WINOUT  IGLOBAL            EDWIN RIVERA ALMAYDA    45689481
# ...

# %%
pd.read_excel('C:\\Users\\Administrador_BI\\Desktop\\ABRAHAM\\GESTION WIN - SJM.xlsx')
# Out:
#      LIST_ID CAMPAÑA      FECHA       TMO  STATUS                TIPIFICACION  \
# 0        408  WINOUT 2025-10-01  00:20:38  2CNE03     AUTORIZA- SIN COBERTURA
# 1        404  WINOUT 2025-10-01  00:12:44  1CEF02         AUTORIZA - AGENDADO
# 2        404  WINOUT 2025-10-01  00:08:35  2CNE03     AUTORIZA- SIN COBERTURA
# 3        408  WINOUT 2025-10-01  00:04:53  2CNE01     AUTORIZA- CORTA LLAMADA
# 4        404  WINOUT 2025-10-01  00:03:57  2CNE01     AUTORIZA- CORTA LLAMADA
# ..       ...     ...        ...       ...     ...                         ...
# 157      404  WINOUT 2025-10-01  00:00:10  2CNE01     AUTORIZA- CORTA LLAMADA
# 158      407  WINOUT 2025-10-01  00:00:08  2CNE01     AUTORIZA- CORTA LLAMADA
# 159      407  WINOUT 2025-10-01  00:00:05  2CNE01     AUTORIZA- CORTA LLAMADA
# 160      407  WINOUT 2025-10-01  00:00:51  1CEF10  AUTORIZA - VOLVER A LLAMAR
# 161      404  WINOUT 2025-10-01  00:00:03  1CEF10  AUTORIZA - VOLVER A LLAMAR
#
# ...

# %%
# nrows
pd.read_excel('C:\\Users\\Administrador_BI\\Desktop\\ABRAHAM\\GESTION WIN - SJM.xlsx', nrows=5)
# Out:
#    LIST_ID CAMPAÑA      FECHA       TMO  STATUS             TIPIFICACION  \
# 0      408  WINOUT 2025-10-01  00:20:38  2CNE03  AUTORIZA- SIN COBERTURA
# 1      404  WINOUT 2025-10-01  00:12:44  1CEF02      AUTORIZA - AGENDADO
# 2      404  WINOUT 2025-10-01  00:08:35  2CNE03  AUTORIZA- SIN COBERTURA
# 3      408  WINOUT 2025-10-01  00:04:53  2CNE01  AUTORIZA- CORTA LLAMADA
# 4      404  WINOUT 2025-10-01  00:03:57  2CNE01  AUTORIZA- CORTA LLAMADA
#
#     TELEFONO       DNI                           AGENTE TERMINO_LLAMADA  \
# 0  968050812  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 1  950168047  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 2  945853311  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 3  972819271  46691128  HAUDE DAVID CALDERON SAN MIGUEL         CLIENTE
# 4  955258851  46691128  HAUDE DAVID CALDERON SAN MIGUEL          AGENTE
#
#   TIPO_LLAMADA      GESTION  AGENDADO  VENTA  VOLVER A LLAMAR  CORTA LLAMADA  \
# ...

# %% [markdown]
# ## usecols

# %%
# usecols
pd.read_excel('C:\\Users\\Administrador_BI\\Desktop\\ABRAHAM\\GESTION WIN - SJM.xlsx', usecols=['LIST_ID','CAMPAÑA','AGENTE'])
# Out:
#      LIST_ID CAMPAÑA                           AGENTE
# 0        408  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 1        404  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 2        404  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 3        408  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 4        404  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# ..       ...     ...                              ...
# 157      404  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 158      407  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 159      407  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 160      407  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
# 161      404  WINOUT  HAUDE DAVID CALDERON SAN MIGUEL
#
# [162 rows x 3 columns]

# %%
combo = pd.read_excel('C:\\Users\\Administrador_BI\\Desktop\\ABRAHAM\\GESTION WIN - SJM.xlsx', sheet_name=4)
combo
# Out:
#       504  WINOUT 2025-10-01 00:00:00  00:00:00  3NCO03  \
# 0     404  WINOUT          2025-10-01  00:00:00  3NCO01
# 1     404  WINOUT          2025-10-01  00:00:00  3NCO01
# 2     404  WINOUT          2025-10-01  00:00:00  3NCO01
# 3     404  WINOUT          2025-10-01  00:00:00  1CEF02
# 4     998  WINOUT          2025-10-01  00:00:00  3NCO01
# ...   ...     ...                 ...       ...     ...
# 7740  404  WINOUT          2025-10-01  00:07:05  1CEF02
# 7741  404  WINOUT          2025-10-01  00:07:13  1CEF09
# 7742  407  WINOUT          2025-10-01  00:07:22  1CEF02
# 7743  408  WINOUT          2025-10-01  00:07:24  2CNE07
# 7744  408  WINOUT          2025-10-01  00:07:26  2CNE03
#
#                       CASILLA DE VOZ  988000723  46691128  \
# 0                        NO CONTESTA  968230838  73285107
# 1                        NO CONTESTA  968230838  73285107
# 2                        NO CONTESTA  960370449  73003562
# ...

# %%
# Para guardaer un excel modificado con pyton
import pandas as pd

bodo = pd.read_excel('C:\\Users\\Administrador_BI\\Desktop\\GESTION WIN - SJM.xlsx', header=None, 
    names=[
        'LIST_ID','CAMPAÑA','FECHA','TMO','STATUS','TIPIFICACION',
        'TELEFONO','DNI','AGENTE','TERMINO_LLAMADA','TIPO_LLAMADA',
        'GESTION','AGENDADO','VENTA','VOLVER A LLAMAR',
        'CORTA LLAMADA','TIPOLOGÌA'
    ], sheet_name='combo'
)
bodo.to_excel(r'C:\Users\Administrador_BI\Desktop\nuevo.xlsx', index=False)
