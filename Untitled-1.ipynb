# %%
import pandas as pd

# %%
ventas = pd.Series([1000,2000,3000])

# %%
ventas
# Out:
# 0    1000
# 1    2000
# 2    3000
# dtype: int64

# %%
paises = pd.Series(['Peru','Colombia','Chile'])
poblacion = pd.Series([1000000,2000000,3000000])
mundial = pd.DataFrame({'Paises': paises, 'Poblaciones': poblacion})

mundial
# Out:
# (     Paises  Poblaciones
#  0      Peru      1000000
#  1  Colombia      2000000
#  2     Chile      3000000,)

# %%
mundial = pd.DataFrame({
    'Paises': ['Perú', 'Colombia', 'Chile'],
    'Poblaciones': [1000000, 2000000, 3000000]
}, index=['PE', 'CO', 'CL'])

mundial
# Out:
#       Paises  Poblaciones
# PE      Perú      1000000
# CO  Colombia      2000000
# CL     Chile      3000000

# %%
Goleadores = pd.DataFrame({
    'jugador' : ['Cristiano','Messi','Neymar'],
    'goles' : [955,856,485]
},index=['POR','ARG','BRA'])

Goleadores
# Out:
#        jugador  goles
# POR  Cristiano    955
# ARG      Messi    856
# BRA     Neymar    485

# %%
#Goleadores.loc['POL'] = 'Lewandoski', 702
#Goleadores.loc[2,'jugador'] = 'Paolo' 
#Goleadores['Edad'] = [36, 32, 37, 39,35] ADD COLUMN NEW
#Goleadores.drop('PER', inplace=True)
#Goleadores.rename(index={2: 'PER'}, inplace=True)
#Goleadores.set_index('', inplace=True)

Goleadores
# Out:
#         jugador goles  Edad
# POR   Cristiano   955    36
# ARG       Messi   856    32
# BRA      Neymar   752    37
# PER       Paolo   245    39
# POL  Lewandoski   702    35

# %%
data = {
    "Agente": ["Ana", "Luis", "Carlos"],
    "Ventas": [10, 15, 7],
    "Estado": ["Activo", "Activo", "Cesado"]
}

df = pd.DataFrame(data)
df
# Out:
#    Agente  Ventas  Estado
# 0     Ana      10  Activo
# 1    Luis      15  Activo
# 2  Carlos       7  Cesado

# %%
paises = pd.Series(['Peru','Chile','Argentina','Uruguay','Brasil'])

paises
# Out:
# 0         Peru
# 1        Chile
# 2    Argentina
# 3      Uruguay
# 4       Brasil
# dtype: object

# %%
poblacion = pd.Series([34000000, 51000000, 19000000, 17000000, 125000000])
poblacion
# Out:
# 0     34000000
# 1     51000000
# 2     19000000
# 3     17000000
# 4    125000000
# dtype: int64

# %%
#modificar list
poblacion[2] = 18050000
poblacion
# Out:
# 0     34000000
# 1     51000000
# 2     18050000
# 3     17000000
# 4    125000000
# dtype: int64

# %%
paises.loc[1] = 'Chile'
paises
# Out:
# 0         Peru
# 1        Chile
# 2    Argentina
# 3      Uruguay
# 4       Brasil
# 5     Colombia
# dtype: object

# %%
poblacion.loc[5] = 654313654
poblacion
# Out:
# 0     34000000
# 1     51000000
# 2     18050000
# 3     17000000
# 4    125000000
# 5    654313654
# dtype: int64

# %%
poblacion.iloc[0] = 'Venezuela'
poblacion
# Out:
# C:\Users\Administrador_BI\AppData\Local\Temp\ipykernel_377704\882865617.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Venezuela' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   poblacion.iloc[0] = 'Venezuela'
# 0    Venezuela
# 1     51000000
# 2     18050000
# 3     17000000
# 4    125000000
# 5    654313654
# dtype: object

# %%
poblacion
# Out:
# 1     51000000
# 2     18050000
# 3     17000000
# 4    125000000
# 5    654313654
# dtype: object

# %%
poblacion.iloc[0] = 654631654654
poblacion
# Out:
# 1    654631654654
# 2        18050000
# 3        17000000
# 4       125000000
# 5       654313654
# dtype: object

# %%
paises
# Out:
# 0         Peru
# 1        Chile
# 2    Argentina
# 3      Uruguay
# 4       Brasil
# 5     Colombia
# dtype: object

# %%
poblacion
# Out:
# 1    654631654654
# 2        18050000
# 3        17000000
# 4       125000000
# 5       654313654
# dtype: object

# %%
poblacion[0]= 645413132
poblacion
# Out:
# 1    654631654654
# 2        18050000
# 3        17000000
# 4       125000000
# 5       654313654
# 0       645413132
# dtype: object

# %%
poblacion
# Out:
# 1    654631654654
# 2        18050000
# 3        17000000
# 4       125000000
# 5       654313654
# 0       645413132
# dtype: object

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel(r"C:\Users\Administrador_BI\Downloads\bd_dic.xlsx")

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   list_id                 1048575 non-null  int64
#  1   list_name               1048575 non-null  object
#  2   lead_id                 1048575 non-null  int64
#  3   campaign_id             1048575 non-null  object
#  4   Fecha                   1048575 non-null  datetime64[ns]
#  5   Hora                    1048575 non-null  object
#  6   Duracion                1048547 non-null  float64
#  7   Tip                     937235 non-null   object
#  8   Resultado_Carrier       1025668 non-null  object
#  9   Carrier                 1025668 non-null  float64
#  10  phone_number            1048575 non-null  object
#  11  Usuario                 1048575 non-null  object
#  12  Agente                  1048575 non-null  object
# ...

# %%
df['DEPARTAMENTO_PROVINCIA'] = df['DEPARTAMENTO_PROVINCIA'].astype(str)

# %%
df['depart'] = 0
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   list_id                 1048575 non-null  int64
#  1   list_name               1048575 non-null  object
#  2   lead_id                 1048575 non-null  int64
#  3   campaign_id             1048575 non-null  object
#  4   Fecha                   1048575 non-null  datetime64[ns]
#  5   Hora                    1048575 non-null  object
#  6   Duracion                1048547 non-null  float64
#  7   Tip                     937235 non-null   object
#  8   Resultado_Carrier       1025668 non-null  object
#  9   Carrier                 1025668 non-null  float64
#  10  phone_number            1048575 non-null  object
#  11  Usuario                 1048575 non-null  object
#  12  Agente                  1048575 non-null  object
# ...

# %%
mask_arequipa = df['DEPARTAMENTO_PROVINCIA'].str.contains('AREQUIPA', case=False, na=False)

# %%
df.loc[mask_arequipa, 'depart'] = 3

# %%
df_arequipa = df[df['depart'] == 3]

# %%
df.loc[df['depart'] == 3, 'DEPARTAMENTO_PROVINCIA'] = 'AREQUIPA'

# %%
df[df['depart'] == 3][['DEPARTAMENTO_PROVINCIA', 'depart']].head(20)

# %%
df['depart'].value_counts()
# Out:
# depart
# 1    811982
# 0    207188
# 3     23808
# 2      5597
# Name: count, dtype: int64

# %%
df.to_csv(
    r"C:\Users\Administrador_BI\Desktop\archivo_limpioS.csv",
    index=False,
    encoding="utf-8-sig"
)
