# %%
import pandas as pd

# %%
df = pd.DataFrame = ({
                    "NOMBRE" : ["MARIA", "PABLO","JOSE",],
                    "APELLIDO" : ["ISASI","SUAREZ","MONTES"],
                    "EDAD" : [39,40,32]
                    
                    })

# %%
df
# Out:
# {'NOMBRE': ['MARIA', 'PABLO', 'JOSE'],
#  'APELLIDO': ['ISASI', 'SUAREZ', 'MONTES'],
#  'EDAD': [39, 40, 32]}

# %%
import pandas as pd

paises = pd.Series(['Peru','Chile','Bolivia'])
poblacion = pd.Series([100000000,2200000000,300000000])

df = pd.DataFrame({'Paises' : paises, 'Poblaciones' : poblacion})

# %%
df.
# Out:
# 0       Peru
# 1      Chile
# 2    Bolivia
# Name: Paises, dtype: object
